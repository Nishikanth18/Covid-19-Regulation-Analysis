# %%
import pandas as pd
from scipy.stats import ttest_ind, pearsonr

# %%
df = pd.read_excel('NewCorr/2g_new.xlsx')

# %%
df.head()
# Out:
#         Location  Infections  deaths mask  Masks  Total Floor Space  \
# 0      Ahrweiler       19256      38   No      0              78703
# 1   Altenkirchen       23304      38   No      0              64238
# 2    Alzey-Worms       26284      64   No      0              58807
# 3   Bad Dürkheim       23045      43   No      0              59464
# 4  Bad Kreuznach       36662      83   No      0              86389
#
#    Residential Settlement (% of area of floor space)  \
# 0                                           3.206993
# 1                                           6.149008
# 2                                           3.451970
# 3                                           3.713171
# 4                                           3.283983
#
#    Industrial and Commercial Settlement (%)  Sports, leisure, recreation (%)  \
# 0                                  0.998691                         1.644156
# 1                                  1.628320                         0.899779
# 2                                  1.226045                         1.816110
# 3                                  1.072918                         2.097067
# 4                                  1.325400                         1.862506
#
#    Other (%)  ...  Water Bodies (%)  Total Population  Female   Male  \
# 0   1.288388  ...          1.617473            130479   66135  64344
# 1   1.460195  ...          0.891995            129087   65144  63943
# 2   1.947047  ...          1.591647            130715   65751  64964
# 3   1.439526  ...          0.662586            133004   67901  65103
# 4   1.842827  ...          0.971188            158746   81197  77549
#
#    (Female) % of Population  (Male) % of Population  \
# 0                 50.686317               49.313683
# 1                 50.465190               49.534810
# 2                 50.301037               49.698963
# 3                 51.051848               48.948152
# 4                 51.149005               48.850995
#
#    (Female) % of Foreigner_s Population  (Male) % of Foreigner_s Population  \
# 0                             46.391909                           53.608091
# 1                             46.036202                           53.963798
# 2                             45.440613                           54.559387
# 3                             47.748691                           52.251309
# 4                             48.613890                           51.386110
#
#    % of Total Population  Inhabitants per km2
# 0              10.079017           165.788477
# 1               8.003130           200.949965
# 2               9.983552           222.278045
# 3               8.616282           223.672048
# 4              11.020750           183.756662
#
# [5 rows x 24 columns]

# %%
columns = list(df.columns)

# %%
columns
# Out:
# ['Location',
#  'Infections',
#  'deaths',
#  'mask',
#  'Masks',
#  'Total Floor Space',
#  'Residential Settlement (% of area of floor space)',
#  'Industrial and Commercial Settlement (%)',
#  'Sports, leisure, recreation (%)',
#  'Other (%)',
#  'Traffic/Transport (%)',
#  'Agriculture  (%)',
#  'Forest (%)',
#  'Others (%)',
#  'Water Bodies (%)',
#  'Total Population',
#  'Female',
#  'Male',
#  '(Female) % of Population',
#  '(Male) % of Population',
#  '(Female) % of Foreigner_s Population',
#  '(Male) % of Foreigner_s Population',
#  '% of Total Population',
#  'Inhabitants per km2']

# %%
# Disregard the Location and mask columns as they are non-numeric
# the mask column has also been stored as a boolean value in the Masks column

columns.remove("Location")
columns.remove("mask")

# %%
columns
# Out:
# ['Infections',
#  'deaths',
#  'Masks',
#  'Total Floor Space',
#  'Residential Settlement (% of area of floor space)',
#  'Industrial and Commercial Settlement (%)',
#  'Sports, leisure, recreation (%)',
#  'Other (%)',
#  'Traffic/Transport (%)',
#  'Agriculture  (%)',
#  'Forest (%)',
#  'Others (%)',
#  'Water Bodies (%)',
#  'Total Population',
#  'Female',
#  'Male',
#  '(Female) % of Population',
#  '(Male) % of Population',
#  '(Female) % of Foreigner_s Population',
#  '(Male) % of Foreigner_s Population',
#  '% of Total Population',
#  'Inhabitants per km2']

# %%
# Result WITH basic interpretations

print("______" * 10)
print("\n")
print("Dataset: 2g")
print("\n")
print("______" * 10)
print("\n")

# t-test and r-test for each pair of columns
# we iterate through every column and test the hypothesis against each pair

for i in range(len(columns)):
    for j in range(i + 1, len(columns)):
        col1 = columns[i]
        col2 = columns[j]
        print(f"t-test and r-test for {col1} and {col2}")
        print("****" * 10)
        
        # Calculating the t-statistic and p-value for it
        t, p = ttest_ind(df[col1], df[col2])
        
        # Calculating the r-value and its significant p-value
        r, p_r = pearsonr(df[col1], df[col2])
        
        # The p-values have been considered for up to 5 decimal places as we
        # need it to interpret it against the level of significance (0.05)
        
        print(f"t-statistic: {t:.2f}")
        print(f"p-value: {p:.5f}")
        print(f"r-value: {r:.2f}")
        print(f"p-value (r-test): {p_r:.5f}")
        
        #Adding basic interpretations for each variable
        print("\nInterpretations:")
        print("......" * 10)

        if p < 0.05:
            print(f"1. p-value (t) {p:.5f} < 0.05 :- there is a statistically significant difference between the two groups.")
        else:
            print(f"1. p-value (t) {p:.5f} > 0.05 :- there is not a statistically significant difference between the two groups.")
        if abs(r) >= 0.7:
            print(f"2. {r:.2f} >= 0.7 :- strong positive or negative correlation between the two variables.")
        elif abs(r) >= 0.3:
            print(f"2. {r:.2f} >= 0.3 :- moderate positive or negative correlation between the two variables.")
        else:
            print(f"2. {r:.2f} < 0.3 :- weak or no correlation between the two variables.")
        if p_r < 0.05:
            print(f"3. p-value (r) {p_r:.5f} < 0.05 :- there is a statistically significant correlation between the two variables.")
        else:
            print(f"3. p-value (r) {p_r:.5f} > 0.05 :-there is not a statistically significant correlation between the two variables.")
        print("\n")
# Out:
# ____________________________________________________________
#
#
# Dataset: 2g
#
#
# ____________________________________________________________
#
#
# t-test and r-test for Infections and deaths
# ****************************************
# t-statistic: 12.44
# p-value: 0.00000
# r-value: 0.34
# p-value (r-test): 0.04541
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.34 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.04541 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Masks
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Total Floor Space
# ****************************************
# t-statistic: -4.89
# p-value: 0.00001
# r-value: 0.29
# p-value (r-test): 0.08821
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00001 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.29 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.08821 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Residential Settlement (% of area of floor space)
# ****************************************
# t-statistic: 12.45
# p-value: 0.00000
# r-value: -0.04
# p-value (r-test): 0.83027
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.04 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.83027 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Industrial and Commercial Settlement (%)
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: -0.17
# p-value (r-test): 0.33538
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.17 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.33538 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: -0.14
# p-value (r-test): 0.41430
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.14 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.41430 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Other (%)
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: -0.02
# p-value (r-test): 0.89919
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.02 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.89919 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Traffic/Transport (%)
# ****************************************
# t-statistic: 12.45
# p-value: 0.00000
# r-value: -0.06
# p-value (r-test): 0.73498
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.06 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.73498 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Agriculture  (%)
# ****************************************
# t-statistic: 12.43
# p-value: 0.00000
# r-value: 0.17
# p-value (r-test): 0.32256
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.17 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.32256 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Forest (%)
# ****************************************
# t-statistic: 12.44
# p-value: 0.00000
# r-value: -0.08
# p-value (r-test): 0.65831
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.08 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.65831 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Others (%)
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: 0.20
# p-value (r-test): 0.24836
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.20 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.24836 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Water Bodies (%)
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: -0.02
# p-value (r-test): 0.89881
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.02 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.89881 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Total Population
# ****************************************
# t-statistic: -10.52
# p-value: 0.00000
# r-value: 0.92
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.92 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Female
# ****************************************
# t-statistic: -7.68
# p-value: 0.00000
# r-value: 0.92
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.92 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Male
# ****************************************
# t-statistic: -7.57
# p-value: 0.00000
# r-value: 0.91
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.91 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and (Female) % of Population
# ****************************************
# t-statistic: 12.43
# p-value: 0.00000
# r-value: -0.01
# p-value (r-test): 0.95028
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.01 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.95028 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and (Male) % of Population
# ****************************************
# t-statistic: 12.43
# p-value: 0.00000
# r-value: 0.01
# p-value (r-test): 0.95028
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.01 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.95028 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 12.43
# p-value: 0.00000
# r-value: 0.25
# p-value (r-test): 0.14508
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.25 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.14508 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: 12.43
# p-value: 0.00000
# r-value: -0.25
# p-value (r-test): 0.14508
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.25 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.14508 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and % of Total Population
# ****************************************
# t-statistic: 12.45
# p-value: 0.00000
# r-value: -0.13
# p-value (r-test): 0.44417
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.13 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.44417 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Infections and Inhabitants per km2
# ****************************************
# t-statistic: 12.17
# p-value: 0.00000
# r-value: 0.01
# p-value (r-test): 0.97682
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.01 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.97682 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Masks
# ****************************************
# t-statistic: 10.54
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Total Floor Space
# ****************************************
# t-statistic: -8.30
# p-value: 0.00000
# r-value: 0.18
# p-value (r-test): 0.28315
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.18 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.28315 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Residential Settlement (% of area of floor space)
# ****************************************
# t-statistic: 8.72
# p-value: 0.00000
# r-value: -0.14
# p-value (r-test): 0.39889
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.14 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.39889 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Industrial and Commercial Settlement (%)
# ****************************************
# t-statistic: 9.49
# p-value: 0.00000
# r-value: -0.05
# p-value (r-test): 0.77103
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.05 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.77103 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: 9.73
# p-value: 0.00000
# r-value: -0.17
# p-value (r-test): 0.31350
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.17 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.31350 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Other (%)
# ****************************************
# t-statistic: 9.67
# p-value: 0.00000
# r-value: -0.12
# p-value (r-test): 0.48949
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.12 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.48949 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Traffic/Transport (%)
# ****************************************
# t-statistic: 8.23
# p-value: 0.00000
# r-value: -0.14
# p-value (r-test): 0.42487
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.14 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.42487 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Agriculture  (%)
# ****************************************
# t-statistic: -1.05
# p-value: 0.29763
# r-value: -0.02
# p-value (r-test): 0.91387
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.29763 > 0.05 :- there is not a statistically significant difference between the two groups.
# 2. -0.02 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.91387 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Forest (%)
# ****************************************
# t-statistic: -0.03
# p-value: 0.97634
# r-value: 0.15
# p-value (r-test): 0.37952
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.97634 > 0.05 :- there is not a statistically significant difference between the two groups.
# 2. 0.15 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.37952 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Others (%)
# ****************************************
# t-statistic: 9.83
# p-value: 0.00000
# r-value: -0.27
# p-value (r-test): 0.11540
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.27 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.11540 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Water Bodies (%)
# ****************************************
# t-statistic: 9.84
# p-value: 0.00000
# r-value: -0.24
# p-value (r-test): 0.15436
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.24 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.15436 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Total Population
# ****************************************
# t-statistic: -13.23
# p-value: 0.00000
# r-value: 0.28
# p-value (r-test): 0.09221
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.28 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.09221 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.28
# p-value (r-test): 0.09872
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.28 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.09872 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Male
# ****************************************
# t-statistic: -13.25
# p-value: 0.00000
# r-value: 0.29
# p-value (r-test): 0.08602
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.29 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.08602 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and (Female) % of Population
# ****************************************
# t-statistic: -4.73
# p-value: 0.00001
# r-value: -0.29
# p-value (r-test): 0.08876
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00001 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.29 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.08876 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and (Male) % of Population
# ****************************************
# t-statistic: -4.37
# p-value: 0.00004
# r-value: 0.29
# p-value (r-test): 0.08876
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00004 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.29 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.08876 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -3.66
# p-value: 0.00048
# r-value: -0.03
# p-value (r-test): 0.87602
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00048 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.03 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.87602 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -5.43
# p-value: 0.00000
# r-value: 0.03
# p-value (r-test): 0.87602
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.03 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.87602 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and % of Total Population
# ****************************************
# t-statistic: 6.85
# p-value: 0.00000
# r-value: 0.04
# p-value (r-test): 0.81206
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.04 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.81206 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for deaths and Inhabitants per km2
# ****************************************
# t-statistic: -4.81
# p-value: 0.00001
# r-value: -0.12
# p-value (r-test): 0.48667
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00001 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.12 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.48667 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Total Floor Space
# ****************************************
# t-statistic: -8.30
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Residential Settlement (% of area of floor space)
# ****************************************
# t-statistic: -9.97
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Industrial and Commercial Settlement (%)
# ****************************************
# t-statistic: -5.54
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: -8.32
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Other (%)
# ****************************************
# t-statistic: -9.22
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Traffic/Transport (%)
# ****************************************
# t-statistic: -17.40
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Agriculture  (%)
# ****************************************
# t-statistic: -17.42
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Forest (%)
# ****************************************
# t-statistic: -12.30
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Others (%)
# ****************************************
# t-statistic: -14.90
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Water Bodies (%)
# ****************************************
# t-statistic: -5.71
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Total Population
# ****************************************
# t-statistic: -13.24
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Male
# ****************************************
# t-statistic: -13.26
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and (Female) % of Population
# ****************************************
# t-statistic: -542.70
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and (Male) % of Population
# ****************************************
# t-statistic: -530.03
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -273.02
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -307.00
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and % of Total Population
# ****************************************
# t-statistic: -15.74
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Masks and Inhabitants per km2
# ****************************************
# t-statistic: -5.21
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. nan < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) nan > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Residential Settlement (% of area of floor space)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.80
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.80 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Industrial and Commercial Settlement (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.66
# p-value (r-test): 0.00001
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.66 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.00001 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.74
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.74 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Other (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.72
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.72 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Traffic/Transport (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.69
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.69 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Agriculture  (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: 0.16
# p-value (r-test): 0.34851
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.16 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.34851 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Forest (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: 0.47
# p-value (r-test): 0.00384
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.47 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.00384 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Others (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: 0.13
# p-value (r-test): 0.46046
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.13 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.46046 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Water Bodies (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.46
# p-value (r-test): 0.00530
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.46 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.00530 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Total Population
# ****************************************
# t-statistic: -5.40
# p-value: 0.00000
# r-value: 0.26
# p-value (r-test): 0.13183
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.26 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.13183 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Female
# ****************************************
# t-statistic: -0.30
# p-value: 0.76154
# r-value: 0.25
# p-value (r-test): 0.14406
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.76154 > 0.05 :- there is not a statistically significant difference between the two groups.
# 2. 0.25 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.14406 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Male
# ****************************************
# t-statistic: -0.14
# p-value: 0.88574
# r-value: 0.26
# p-value (r-test): 0.12028
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.88574 > 0.05 :- there is not a statistically significant difference between the two groups.
# 2. 0.26 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.12028 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and (Female) % of Population
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.47
# p-value (r-test): 0.00420
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.47 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.00420 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and (Male) % of Population
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: 0.47
# p-value (r-test): 0.00420
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.47 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.00420 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: 0.21
# p-value (r-test): 0.23015
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.21 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.23015 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.21
# p-value (r-test): 0.23015
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.21 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.23015 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and % of Total Population
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.53
# p-value (r-test): 0.00083
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.53 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.00083 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Total Floor Space and Inhabitants per km2
# ****************************************
# t-statistic: 8.23
# p-value: 0.00000
# r-value: -0.69
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.69 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Industrial and Commercial Settlement (%)
# ****************************************
# t-statistic: 3.27
# p-value: 0.00167
# r-value: 0.85
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00167 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.85 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: 4.78
# p-value: 0.00001
# r-value: 0.88
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00001 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.88 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Other (%)
# ****************************************
# t-statistic: 4.53
# p-value: 0.00002
# r-value: 0.92
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00002 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.92 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Traffic/Transport (%)
# ****************************************
# t-statistic: -2.56
# p-value: 0.01276
# r-value: 0.89
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.01276 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.89 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Agriculture  (%)
# ****************************************
# t-statistic: -14.46
# p-value: 0.00000
# r-value: -0.25
# p-value (r-test): 0.14658
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.25 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.14658 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Forest (%)
# ****************************************
# t-statistic: -10.13
# p-value: 0.00000
# r-value: -0.56
# p-value (r-test): 0.00041
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.56 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.00041 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Others (%)
# ****************************************
# t-statistic: 5.66
# p-value: 0.00000
# r-value: -0.03
# p-value (r-test): 0.84229
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.03 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.84229 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Water Bodies (%)
# ****************************************
# t-statistic: 5.18
# p-value: 0.00000
# r-value: 0.53
# p-value (r-test): 0.00086
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.53 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.00086 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Total Population
# ****************************************
# t-statistic: -13.24
# p-value: 0.00000
# r-value: 0.10
# p-value (r-test): 0.57028
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.10 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.57028 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.10
# p-value (r-test): 0.55152
#
# Interpretations:
# ............................................................
# ...
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.15 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.36709 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Female and Male
# ****************************************
# t-statistic: 0.21
# p-value: 0.83357
# r-value: 1.00
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.83357 > 0.05 :- there is not a statistically significant difference between the two groups.
# 2. 1.00 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Female and (Female) % of Population
# ****************************************
# t-statistic: 13.20
# p-value: 0.00000
# r-value: -0.09
# p-value (r-test): 0.60135
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.09 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.60135 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Female and (Male) % of Population
# ****************************************
# t-statistic: 13.20
# p-value: 0.00000
# r-value: 0.09
# p-value (r-test): 0.60135
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.09 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.60135 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Female and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 13.20
# p-value: 0.00000
# r-value: 0.16
# p-value (r-test): 0.34940
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.16 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.34940 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Female and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: 13.20
# p-value: 0.00000
# r-value: -0.16
# p-value (r-test): 0.34940
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.16 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.34940 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Female and % of Total Population
# ****************************************
# t-statistic: 13.21
# p-value: 0.00000
# r-value: 0.07
# p-value (r-test): 0.69819
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.07 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.69819 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Female and Inhabitants per km2
# ****************************************
# t-statistic: 13.10
# p-value: 0.00000
# r-value: 0.16
# p-value (r-test): 0.35658
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.16 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.35658 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Male and (Female) % of Population
# ****************************************
# t-statistic: 13.25
# p-value: 0.00000
# r-value: -0.13
# p-value (r-test): 0.45726
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.13 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.45726 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Male and (Male) % of Population
# ****************************************
# t-statistic: 13.25
# p-value: 0.00000
# r-value: 0.13
# p-value (r-test): 0.45726
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.13 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.45726 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Male and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 13.25
# p-value: 0.00000
# r-value: 0.14
# p-value (r-test): 0.40247
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.14 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.40247 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Male and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: 13.25
# p-value: 0.00000
# r-value: -0.14
# p-value (r-test): 0.40247
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.14 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.40247 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Male and % of Total Population
# ****************************************
# t-statistic: 13.26
# p-value: 0.00000
# r-value: 0.07
# p-value (r-test): 0.66514
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.07 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.66514 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for Male and Inhabitants per km2
# ****************************************
# t-statistic: 13.15
# p-value: 0.00000
# r-value: 0.15
# p-value (r-test): 0.37829
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.15 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.37829 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Female) % of Population and (Male) % of Population
# ****************************************
# t-statistic: 8.95
# p-value: 0.00000
# r-value: -1.00
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -1.00 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Female) % of Population and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 17.96
# p-value: 0.00000
# r-value: 0.33
# p-value (r-test): 0.05306
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.33 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.05306 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Female) % of Population and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -11.94
# p-value: 0.00000
# r-value: -0.33
# p-value (r-test): 0.05306
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.33 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.05306 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Female) % of Population and % of Total Population
# ****************************************
# t-statistic: 52.07
# p-value: 0.00000
# r-value: -0.06
# p-value (r-test): 0.74293
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.06 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.74293 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Female) % of Population and Inhabitants per km2
# ****************************************
# t-statistic: -4.64
# p-value: 0.00002
# r-value: 0.22
# p-value (r-test): 0.20083
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00002 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.22 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.20083 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Male) % of Population and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 11.94
# p-value: 0.00000
# r-value: -0.33
# p-value (r-test): 0.05306
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.33 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.05306 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Male) % of Population and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -17.96
# p-value: 0.00000
# r-value: 0.33
# p-value (r-test): 0.05306
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.33 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.05306 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Male) % of Population and % of Total Population
# ****************************************
# t-statistic: 50.49
# p-value: 0.00000
# r-value: 0.06
# p-value (r-test): 0.74293
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.06 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.74293 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Male) % of Population and Inhabitants per km2
# ****************************************
# t-statistic: -4.66
# p-value: 0.00001
# r-value: -0.22
# p-value (r-test): 0.20083
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00001 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.22 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.20083 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Female) % of Foreigner_s Population and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -24.03
# p-value: 0.00000
# r-value: -1.00
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -1.00 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Female) % of Foreigner_s Population and % of Total Population
# ****************************************
# t-statistic: 46.49
# p-value: 0.00000
# r-value: -0.32
# p-value (r-test): 0.05450
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.32 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.05450 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Female) % of Foreigner_s Population and Inhabitants per km2
# ****************************************
# t-statistic: -4.68
# p-value: 0.00001
# r-value: -0.16
# p-value (r-test): 0.33847
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00001 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. -0.16 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.33847 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Male) % of Foreigner_s Population and % of Total Population
# ****************************************
# t-statistic: 54.19
# p-value: 0.00000
# r-value: 0.32
# p-value (r-test): 0.05450
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.32 >= 0.3 :- moderate positive or negative correlation between the two variables.
# 3. p-value (r) 0.05450 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for (Male) % of Foreigner_s Population and Inhabitants per km2
# ****************************************
# t-statistic: -4.62
# p-value: 0.00002
# r-value: 0.16
# p-value (r-test): 0.33847
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00002 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.16 < 0.3 :- weak or no correlation between the two variables.
# 3. p-value (r) 0.33847 > 0.05 :-there is not a statistically significant correlation between the two variables.
#
#
# t-test and r-test for % of Total Population and Inhabitants per km2
# ****************************************
# t-statistic: -5.08
# p-value: 0.00000
# r-value: 0.84
# p-value (r-test): 0.00000
#
# Interpretations:
# ............................................................
# 1. p-value (t) 0.00000 < 0.05 :- there is a statistically significant difference between the two groups.
# 2. 0.84 >= 0.7 :- strong positive or negative correlation between the two variables.
# 3. p-value (r) 0.00000 < 0.05 :- there is a statistically significant correlation between the two variables.

# %%
# Result WITHOUT basic interpretation

print("______" * 10)
print("\n")
print("Dataset: 2g")
print("\n")
print("______" * 10)
print("\n")

# t-test and r-test for each pair of columns
# we iterate through every column and test the hypothesis against each pair

for i in range(len(columns)):
    for j in range(i + 1, len(columns)):
        col1 = columns[i]
        col2 = columns[j]
        print(f"t-test and r-test for {col1} and {col2}")
        print("****" * 10)
        
        # Calculating the t-statistic and p-value for it
        t, p = ttest_ind(df[col1], df[col2])
        
        # Calculating the r-value and its significant p-value 
        r, p_r = pearsonr(df[col1], df[col2])
        
        # The p-values have been considered for up to 5 decimal places as we
        # need it to interpret it against the level of significance (0.05)
        
        print(f"t-statistic: {t:.2f}")
        print(f"p-value: {p:.5f}")
        print(f"r-value: {r:.2f}")
        print(f"p-value (r-test): {p_r:.5f}")
        print("\n")
# Out:
# ____________________________________________________________
#
#
# Dataset: 2g
#
#
# ____________________________________________________________
#
#
# t-test and r-test for Infections and deaths
# ****************************************
# t-statistic: 12.44
# p-value: 0.00000
# r-value: 0.34
# p-value (r-test): 0.04541
#
#
# t-test and r-test for Infections and Masks
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Infections and Total Floor Space
# ****************************************
# t-statistic: -4.89
# p-value: 0.00001
# r-value: 0.29
# p-value (r-test): 0.08821
#
#
# t-test and r-test for Infections and Residential Settlement (% of area of floor space)
# ****************************************
# t-statistic: 12.45
# p-value: 0.00000
# r-value: -0.04
# p-value (r-test): 0.83027
#
#
# t-test and r-test for Infections and Industrial and Commercial Settlement (%)
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: -0.17
# p-value (r-test): 0.33538
#
#
# t-test and r-test for Infections and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: -0.14
# p-value (r-test): 0.41430
#
#
# t-test and r-test for Infections and Other (%)
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: -0.02
# p-value (r-test): 0.89919
#
#
# t-test and r-test for Infections and Traffic/Transport (%)
# ****************************************
# t-statistic: 12.45
# p-value: 0.00000
# r-value: -0.06
# p-value (r-test): 0.73498
#
#
# t-test and r-test for Infections and Agriculture  (%)
# ****************************************
# t-statistic: 12.43
# p-value: 0.00000
# r-value: 0.17
# p-value (r-test): 0.32256
#
#
# t-test and r-test for Infections and Forest (%)
# ****************************************
# t-statistic: 12.44
# p-value: 0.00000
# r-value: -0.08
# p-value (r-test): 0.65831
#
#
# t-test and r-test for Infections and Others (%)
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: 0.20
# p-value (r-test): 0.24836
#
#
# t-test and r-test for Infections and Water Bodies (%)
# ****************************************
# t-statistic: 12.46
# p-value: 0.00000
# r-value: -0.02
# p-value (r-test): 0.89881
#
#
# t-test and r-test for Infections and Total Population
# ****************************************
# t-statistic: -10.52
# p-value: 0.00000
# r-value: 0.92
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Infections and Female
# ****************************************
# t-statistic: -7.68
# p-value: 0.00000
# r-value: 0.92
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Infections and Male
# ****************************************
# t-statistic: -7.57
# p-value: 0.00000
# r-value: 0.91
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Infections and (Female) % of Population
# ****************************************
# t-statistic: 12.43
# p-value: 0.00000
# r-value: -0.01
# p-value (r-test): 0.95028
#
#
# t-test and r-test for Infections and (Male) % of Population
# ****************************************
# t-statistic: 12.43
# p-value: 0.00000
# r-value: 0.01
# p-value (r-test): 0.95028
#
#
# t-test and r-test for Infections and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 12.43
# p-value: 0.00000
# r-value: 0.25
# p-value (r-test): 0.14508
#
#
# t-test and r-test for Infections and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: 12.43
# p-value: 0.00000
# r-value: -0.25
# p-value (r-test): 0.14508
#
#
# t-test and r-test for Infections and % of Total Population
# ****************************************
# t-statistic: 12.45
# p-value: 0.00000
# r-value: -0.13
# p-value (r-test): 0.44417
#
#
# t-test and r-test for Infections and Inhabitants per km2
# ****************************************
# t-statistic: 12.17
# p-value: 0.00000
# r-value: 0.01
# p-value (r-test): 0.97682
#
#
# t-test and r-test for deaths and Masks
# ****************************************
# t-statistic: 10.54
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for deaths and Total Floor Space
# ****************************************
# t-statistic: -8.30
# p-value: 0.00000
# r-value: 0.18
# p-value (r-test): 0.28315
#
#
# t-test and r-test for deaths and Residential Settlement (% of area of floor space)
# ****************************************
# t-statistic: 8.72
# p-value: 0.00000
# r-value: -0.14
# p-value (r-test): 0.39889
#
#
# t-test and r-test for deaths and Industrial and Commercial Settlement (%)
# ****************************************
# t-statistic: 9.49
# p-value: 0.00000
# r-value: -0.05
# p-value (r-test): 0.77103
#
#
# t-test and r-test for deaths and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: 9.73
# p-value: 0.00000
# r-value: -0.17
# p-value (r-test): 0.31350
#
#
# t-test and r-test for deaths and Other (%)
# ****************************************
# t-statistic: 9.67
# p-value: 0.00000
# r-value: -0.12
# p-value (r-test): 0.48949
#
#
# t-test and r-test for deaths and Traffic/Transport (%)
# ****************************************
# t-statistic: 8.23
# p-value: 0.00000
# r-value: -0.14
# p-value (r-test): 0.42487
#
#
# t-test and r-test for deaths and Agriculture  (%)
# ****************************************
# t-statistic: -1.05
# p-value: 0.29763
# r-value: -0.02
# p-value (r-test): 0.91387
#
#
# t-test and r-test for deaths and Forest (%)
# ****************************************
# t-statistic: -0.03
# p-value: 0.97634
# r-value: 0.15
# p-value (r-test): 0.37952
#
#
# t-test and r-test for deaths and Others (%)
# ****************************************
# t-statistic: 9.83
# p-value: 0.00000
# r-value: -0.27
# p-value (r-test): 0.11540
#
#
# t-test and r-test for deaths and Water Bodies (%)
# ****************************************
# t-statistic: 9.84
# p-value: 0.00000
# r-value: -0.24
# p-value (r-test): 0.15436
#
#
# t-test and r-test for deaths and Total Population
# ****************************************
# t-statistic: -13.23
# p-value: 0.00000
# r-value: 0.28
# p-value (r-test): 0.09221
#
#
# t-test and r-test for deaths and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.28
# p-value (r-test): 0.09872
#
#
# t-test and r-test for deaths and Male
# ****************************************
# t-statistic: -13.25
# p-value: 0.00000
# r-value: 0.29
# p-value (r-test): 0.08602
#
#
# t-test and r-test for deaths and (Female) % of Population
# ****************************************
# t-statistic: -4.73
# p-value: 0.00001
# r-value: -0.29
# p-value (r-test): 0.08876
#
#
# t-test and r-test for deaths and (Male) % of Population
# ****************************************
# t-statistic: -4.37
# p-value: 0.00004
# r-value: 0.29
# p-value (r-test): 0.08876
#
#
# t-test and r-test for deaths and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -3.66
# p-value: 0.00048
# r-value: -0.03
# p-value (r-test): 0.87602
#
#
# t-test and r-test for deaths and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -5.43
# p-value: 0.00000
# r-value: 0.03
# p-value (r-test): 0.87602
#
#
# t-test and r-test for deaths and % of Total Population
# ****************************************
# t-statistic: 6.85
# p-value: 0.00000
# r-value: 0.04
# p-value (r-test): 0.81206
#
#
# t-test and r-test for deaths and Inhabitants per km2
# ****************************************
# t-statistic: -4.81
# p-value: 0.00001
# r-value: -0.12
# p-value (r-test): 0.48667
#
#
# t-test and r-test for Masks and Total Floor Space
# ****************************************
# t-statistic: -8.30
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Residential Settlement (% of area of floor space)
# ****************************************
# t-statistic: -9.97
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Industrial and Commercial Settlement (%)
# ****************************************
# t-statistic: -5.54
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: -8.32
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Other (%)
# ****************************************
# t-statistic: -9.22
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Traffic/Transport (%)
# ****************************************
# t-statistic: -17.40
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Agriculture  (%)
# ****************************************
# t-statistic: -17.42
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Forest (%)
# ****************************************
# t-statistic: -12.30
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Others (%)
# ****************************************
# t-statistic: -14.90
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Water Bodies (%)
# ****************************************
# t-statistic: -5.71
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Total Population
# ****************************************
# t-statistic: -13.24
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Male
# ****************************************
# t-statistic: -13.26
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and (Female) % of Population
# ****************************************
# t-statistic: -542.70
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and (Male) % of Population
# ****************************************
# t-statistic: -530.03
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -273.02
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -307.00
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and % of Total Population
# ****************************************
# t-statistic: -15.74
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Masks and Inhabitants per km2
# ****************************************
# t-statistic: -5.21
# p-value: 0.00000
# r-value: nan
# p-value (r-test): nan
#
#
# t-test and r-test for Total Floor Space and Residential Settlement (% of area of floor space)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.80
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Total Floor Space and Industrial and Commercial Settlement (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.66
# p-value (r-test): 0.00001
#
#
# t-test and r-test for Total Floor Space and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.74
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Total Floor Space and Other (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.72
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Total Floor Space and Traffic/Transport (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.69
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Total Floor Space and Agriculture  (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: 0.16
# p-value (r-test): 0.34851
#
#
# t-test and r-test for Total Floor Space and Forest (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: 0.47
# p-value (r-test): 0.00384
#
#
# t-test and r-test for Total Floor Space and Others (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: 0.13
# p-value (r-test): 0.46046
#
#
# t-test and r-test for Total Floor Space and Water Bodies (%)
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.46
# p-value (r-test): 0.00530
#
#
# t-test and r-test for Total Floor Space and Total Population
# ****************************************
# t-statistic: -5.40
# p-value: 0.00000
# r-value: 0.26
# p-value (r-test): 0.13183
#
#
# t-test and r-test for Total Floor Space and Female
# ****************************************
# t-statistic: -0.30
# p-value: 0.76154
# r-value: 0.25
# p-value (r-test): 0.14406
#
#
# t-test and r-test for Total Floor Space and Male
# ****************************************
# t-statistic: -0.14
# p-value: 0.88574
# r-value: 0.26
# p-value (r-test): 0.12028
#
#
# t-test and r-test for Total Floor Space and (Female) % of Population
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.47
# p-value (r-test): 0.00420
#
#
# t-test and r-test for Total Floor Space and (Male) % of Population
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: 0.47
# p-value (r-test): 0.00420
#
#
# t-test and r-test for Total Floor Space and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: 0.21
# p-value (r-test): 0.23015
#
#
# t-test and r-test for Total Floor Space and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.21
# p-value (r-test): 0.23015
#
#
# t-test and r-test for Total Floor Space and % of Total Population
# ****************************************
# t-statistic: 8.30
# p-value: 0.00000
# r-value: -0.53
# p-value (r-test): 0.00083
#
#
# t-test and r-test for Total Floor Space and Inhabitants per km2
# ****************************************
# t-statistic: 8.23
# p-value: 0.00000
# r-value: -0.69
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Industrial and Commercial Settlement (%)
# ****************************************
# t-statistic: 3.27
# p-value: 0.00167
# r-value: 0.85
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: 4.78
# p-value: 0.00001
# r-value: 0.88
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Other (%)
# ****************************************
# t-statistic: 4.53
# p-value: 0.00002
# r-value: 0.92
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Traffic/Transport (%)
# ****************************************
# t-statistic: -2.56
# p-value: 0.01276
# r-value: 0.89
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Agriculture  (%)
# ****************************************
# t-statistic: -14.46
# p-value: 0.00000
# r-value: -0.25
# p-value (r-test): 0.14658
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Forest (%)
# ****************************************
# t-statistic: -10.13
# p-value: 0.00000
# r-value: -0.56
# p-value (r-test): 0.00041
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Others (%)
# ****************************************
# t-statistic: 5.66
# p-value: 0.00000
# r-value: -0.03
# p-value (r-test): 0.84229
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Water Bodies (%)
# ****************************************
# t-statistic: 5.18
# p-value: 0.00000
# r-value: 0.53
# p-value (r-test): 0.00086
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Total Population
# ****************************************
# t-statistic: -13.24
# p-value: 0.00000
# r-value: 0.10
# p-value (r-test): 0.57028
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.10
# p-value (r-test): 0.55152
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Male
# ****************************************
# t-statistic: -13.26
# p-value: 0.00000
# r-value: 0.09
# p-value (r-test): 0.59000
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and (Female) % of Population
# ****************************************
# t-statistic: -78.64
# p-value: 0.00000
# r-value: 0.29
# p-value (r-test): 0.08569
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and (Male) % of Population
# ****************************************
# t-statistic: -76.57
# p-value: 0.00000
# r-value: -0.29
# p-value (r-test): 0.08569
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -70.26
# p-value: 0.00000
# r-value: -0.24
# p-value (r-test): 0.16416
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -80.19
# p-value: 0.00000
# r-value: 0.24
# p-value (r-test): 0.16416
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and % of Total Population
# ****************************************
# t-statistic: -6.49
# p-value: 0.00000
# r-value: 0.75
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Residential Settlement (% of area of floor space) and Inhabitants per km2
# ****************************************
# t-statistic: -5.14
# p-value: 0.00000
# r-value: 0.92
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Sports, leisure, recreation (%)
# ****************************************
# t-statistic: 0.79
# p-value: 0.43456
# r-value: 0.92
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Other (%)
# ****************************************
# t-statistic: 0.49
# p-value: 0.62222
# r-value: 0.83
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Traffic/Transport (%)
# ****************************************
# t-statistic: -6.30
# p-value: 0.00000
# r-value: 0.90
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Agriculture  (%)
# ****************************************
# t-statistic: -15.60
# p-value: 0.00000
# r-value: -0.24
# p-value (r-test): 0.15631
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Forest (%)
# ****************************************
# t-statistic: -11.03
# p-value: 0.00000
# r-value: -0.58
# p-value (r-test): 0.00024
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Others (%)
# ****************************************
# t-statistic: 1.29
# p-value: 0.20269
# r-value: 0.03
# p-value (r-test): 0.84794
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Water Bodies (%)
# ****************************************
# t-statistic: 1.39
# p-value: 0.16816
# r-value: 0.64
# p-value (r-test): 0.00003
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Total Population
# ****************************************
# t-statistic: -13.24
# p-value: 0.00000
# r-value: 0.00
# p-value (r-test): 0.98331
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.00
# p-value (r-test): 0.99137
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Male
# ****************************************
# t-statistic: -13.26
# p-value: 0.00000
# r-value: 0.01
# p-value (r-test): 0.97505
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and (Female) % of Population
# ****************************************
# t-statistic: -85.20
# p-value: 0.00000
# r-value: 0.10
# p-value (r-test): 0.54350
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and (Male) % of Population
# ****************************************
# t-statistic: -83.09
# p-value: 0.00000
# r-value: -0.10
# p-value (r-test): 0.54350
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -76.36
# p-value: 0.00000
# r-value: -0.30
# p-value (r-test): 0.07852
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -86.52
# p-value: 0.00000
# r-value: 0.30
# p-value (r-test): 0.07852
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and % of Total Population
# ****************************************
# t-statistic: -9.34
# p-value: 0.00000
# r-value: 0.87
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Industrial and Commercial Settlement (%) and Inhabitants per km2
# ****************************************
# t-statistic: -5.17
# p-value: 0.00000
# r-value: 0.89
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Sports, leisure, recreation (%) and Other (%)
# ****************************************
# t-statistic: -0.43
# p-value: 0.66517
# r-value: 0.88
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Sports, leisure, recreation (%) and Traffic/Transport (%)
# ****************************************
# t-statistic: -9.28
# p-value: 0.00000
# r-value: 0.93
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Sports, leisure, recreation (%) and Agriculture  (%)
# ****************************************
# t-statistic: -16.13
# p-value: 0.00000
# r-value: -0.19
# p-value (r-test): 0.27210
#
#
# t-test and r-test for Sports, leisure, recreation (%) and Forest (%)
# ****************************************
# t-statistic: -11.34
# p-value: 0.00000
# r-value: -0.64
# p-value (r-test): 0.00003
#
#
# t-test and r-test for Sports, leisure, recreation (%) and Others (%)
# ****************************************
# t-statistic: 0.70
# p-value: 0.48745
# r-value: 0.14
# p-value (r-test): 0.40192
#
#
# t-test and r-test for Sports, leisure, recreation (%) and Water Bodies (%)
# ****************************************
# t-statistic: 0.89
# p-value: 0.37585
# r-value: 0.66
# p-value (r-test): 0.00001
#
#
# t-test and r-test for Sports, leisure, recreation (%) and Total Population
# ****************************************
# t-statistic: -13.24
# p-value: 0.00000
# r-value: 0.00
# p-value (r-test): 0.97708
#
#
# t-test and r-test for Sports, leisure, recreation (%) and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.01
# p-value (r-test): 0.96130
#
#
# t-test and r-test for Sports, leisure, recreation (%) and Male
# ****************************************
# t-statistic: -13.26
# p-value: 0.00000
# r-value: 0.00
# p-value (r-test): 0.99330
#
#
# t-test and r-test for Sports, leisure, recreation (%) and (Female) % of Population
# ****************************************
# t-statistic: -149.81
# p-value: 0.00000
# r-value: 0.28
# p-value (r-test): 0.09421
#
#
# t-test and r-test for Sports, leisure, recreation (%) and (Male) % of Population
# ****************************************
# t-statistic: -146.13
# p-value: 0.00000
# r-value: -0.28
# p-value (r-test): 0.09421
#
#
# t-test and r-test for Sports, leisure, recreation (%) and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -126.49
# p-value: 0.00000
# r-value: -0.23
# p-value (r-test): 0.17403
#
#
# t-test and r-test for Sports, leisure, recreation (%) and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -143.14
# p-value: 0.00000
# r-value: 0.23
# p-value (r-test): 0.17403
#
#
# t-test and r-test for Sports, leisure, recreation (%) and % of Total Population
# ****************************************
# t-statistic: -11.36
# p-value: 0.00000
# r-value: 0.83
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Sports, leisure, recreation (%) and Inhabitants per km2
# ****************************************
# t-statistic: -5.18
# p-value: 0.00000
# r-value: 0.93
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Other (%) and Traffic/Transport (%)
# ****************************************
# t-statistic: -9.02
# p-value: 0.00000
# r-value: 0.91
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Other (%) and Agriculture  (%)
# ****************************************
# t-statistic: -16.06
# p-value: 0.00000
# r-value: -0.29
# p-value (r-test): 0.08902
#
#
# t-test and r-test for Other (%) and Forest (%)
# ****************************************
# t-statistic: -11.28
# p-value: 0.00000
# r-value: -0.53
# p-value (r-test): 0.00083
#
#
# t-test and r-test for Other (%) and Others (%)
# ****************************************
# t-statistic: 1.27
# p-value: 0.20838
# r-value: 0.05
# p-value (r-test): 0.78140
#
#
# t-test and r-test for Other (%) and Water Bodies (%)
# ****************************************
# t-statistic: 1.29
# p-value: 0.20045
# r-value: 0.61
# p-value (r-test): 0.00009
#
#
# t-test and r-test for Other (%) and Total Population
# ****************************************
# t-statistic: -13.24
# p-value: 0.00000
# r-value: 0.06
# p-value (r-test): 0.71202
#
#
# t-test and r-test for Other (%) and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.07
# p-value (r-test): 0.69525
#
#
# t-test and r-test for Other (%) and Male
# ****************************************
# t-statistic: -13.26
# p-value: 0.00000
# r-value: 0.06
# p-value (r-test): 0.72951
#
#
# t-test and r-test for Other (%) and (Female) % of Population
# ****************************************
# t-statistic: -153.67
# p-value: 0.00000
# r-value: 0.21
# p-value (r-test): 0.21227
#
#
# t-test and r-test for Other (%) and (Male) % of Population
# ****************************************
# t-statistic: -149.88
# p-value: 0.00000
# r-value: -0.21
# p-value (r-test): 0.21227
#
#
# t-test and r-test for Other (%) and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -129.05
# p-value: 0.00000
# r-value: -0.27
# p-value (r-test): 0.11598
#
#
# t-test and r-test for Other (%) and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -146.11
# p-value: 0.00000
# r-value: 0.27
# p-value (r-test): 0.11598
#
#
# t-test and r-test for Other (%) and % of Total Population
# ****************************************
# t-statistic: -11.18
# p-value: 0.00000
# r-value: 0.78
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Other (%) and Inhabitants per km2
# ****************************************
# t-statistic: -5.18
# p-value: 0.00000
# r-value: 0.93
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Traffic/Transport (%) and Agriculture  (%)
# ****************************************
# t-statistic: -13.86
# p-value: 0.00000
# r-value: -0.11
# p-value (r-test): 0.52686
#
#
# t-test and r-test for Traffic/Transport (%) and Forest (%)
# ****************************************
# t-statistic: -9.58
# p-value: 0.00000
# r-value: -0.69
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Traffic/Transport (%) and Others (%)
# ****************************************
# t-statistic: 11.26
# p-value: 0.00000
# r-value: 0.15
# p-value (r-test): 0.39704
#
#
# t-test and r-test for Traffic/Transport (%) and Water Bodies (%)
# ****************************************
# t-statistic: 9.37
# p-value: 0.00000
# r-value: 0.60
# p-value (r-test): 0.00010
#
#
# t-test and r-test for Traffic/Transport (%) and Total Population
# ****************************************
# t-statistic: -13.24
# p-value: 0.00000
# r-value: 0.07
# p-value (r-test): 0.68218
#
#
# t-test and r-test for Traffic/Transport (%) and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.07
# p-value (r-test): 0.67103
#
#
# t-test and r-test for Traffic/Transport (%) and Male
# ****************************************
# t-statistic: -13.26
# p-value: 0.00000
# r-value: 0.07
# p-value (r-test): 0.69383
#
#
# t-test and r-test for Traffic/Transport (%) and (Female) % of Population
# ****************************************
# t-statistic: -98.68
# p-value: 0.00000
# r-value: 0.23
# p-value (r-test): 0.18402
#
#
# t-test and r-test for Traffic/Transport (%) and (Male) % of Population
# ****************************************
# t-statistic: -95.98
# p-value: 0.00000
# r-value: -0.23
# p-value (r-test): 0.18402
#
#
# t-test and r-test for Traffic/Transport (%) and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -86.02
# p-value: 0.00000
# r-value: -0.26
# p-value (r-test): 0.11843
#
#
# t-test and r-test for Traffic/Transport (%) and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -98.74
# p-value: 0.00000
# r-value: 0.26
# p-value (r-test): 0.11843
#
#
# t-test and r-test for Traffic/Transport (%) and % of Total Population
# ****************************************
# t-statistic: -4.95
# p-value: 0.00000
# r-value: 0.85
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Traffic/Transport (%) and Inhabitants per km2
# ****************************************
# t-statistic: -5.12
# p-value: 0.00000
# r-value: 0.95
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Agriculture  (%) and Forest (%)
# ****************************************
# t-statistic: 1.12
# p-value: 0.26580
# r-value: -0.61
# p-value (r-test): 0.00008
#
#
# t-test and r-test for Agriculture  (%) and Others (%)
# ****************************************
# t-statistic: 16.35
# p-value: 0.00000
# r-value: -0.00
# p-value (r-test): 0.99266
#
#
# t-test and r-test for Agriculture  (%) and Water Bodies (%)
# ****************************************
# t-statistic: 16.25
# p-value: 0.00000
# r-value: -0.14
# p-value (r-test): 0.42859
#
#
# t-test and r-test for Agriculture  (%) and Total Population
# ****************************************
# t-statistic: -13.23
# p-value: 0.00000
# r-value: 0.11
# p-value (r-test): 0.50855
#
#
# t-test and r-test for Agriculture  (%) and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.12
# p-value (r-test): 0.50410
#
#
# t-test and r-test for Agriculture  (%) and Male
# ****************************************
# t-statistic: -13.25
# p-value: 0.00000
# r-value: 0.11
# p-value (r-test): 0.51333
#
#
# t-test and r-test for Agriculture  (%) and (Female) % of Population
# ****************************************
# t-statistic: -5.10
# p-value: 0.00000
# r-value: 0.03
# p-value (r-test): 0.87299
#
#
# t-test and r-test for Agriculture  (%) and (Male) % of Population
# ****************************************
# t-statistic: -4.58
# p-value: 0.00002
# r-value: -0.03
# p-value (r-test): 0.87299
#
#
# t-test and r-test for Agriculture  (%) and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -3.53
# p-value: 0.00074
# r-value: 0.17
# p-value (r-test): 0.32955
#
#
# t-test and r-test for Agriculture  (%) and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -6.13
# p-value: 0.00000
# r-value: -0.17
# p-value (r-test): 0.32955
#
#
# t-test and r-test for Agriculture  (%) and % of Total Population
# ****************************************
# t-statistic: 11.60
# p-value: 0.00000
# r-value: -0.12
# p-value (r-test): 0.48023
#
#
# t-test and r-test for Agriculture  (%) and Inhabitants per km2
# ****************************************
# t-statistic: -4.77
# p-value: 0.00001
# r-value: -0.18
# p-value (r-test): 0.28012
#
#
# t-test and r-test for Forest (%) and Others (%)
# ****************************************
# t-statistic: 11.47
# p-value: 0.00000
# r-value: -0.13
# p-value (r-test): 0.46168
#
#
# t-test and r-test for Forest (%) and Water Bodies (%)
# ****************************************
# t-statistic: 11.46
# p-value: 0.00000
# r-value: -0.49
# p-value (r-test): 0.00246
#
#
# t-test and r-test for Forest (%) and Total Population
# ****************************************
# t-statistic: -13.23
# p-value: 0.00000
# r-value: -0.16
# p-value (r-test): 0.36651
#
#
# t-test and r-test for Forest (%) and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: -0.16
# p-value (r-test): 0.35723
#
#
# t-test and r-test for Forest (%) and Male
# ****************************************
# t-statistic: -13.25
# p-value: 0.00000
# r-value: -0.15
# p-value (r-test): 0.37640
#
#
# t-test and r-test for Forest (%) and (Female) % of Population
# ****************************************
# t-statistic: -5.45
# p-value: 0.00000
# r-value: -0.21
# p-value (r-test): 0.22611
#
#
# t-test and r-test for Forest (%) and (Male) % of Population
# ****************************************
# t-statistic: -5.04
# p-value: 0.00000
# r-value: 0.21
# p-value (r-test): 0.22611
#
#
# t-test and r-test for Forest (%) and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -4.21
# p-value: 0.00007
# r-value: 0.12
# p-value (r-test): 0.49772
#
#
# t-test and r-test for Forest (%) and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -6.26
# p-value: 0.00000
# r-value: -0.12
# p-value (r-test): 0.49772
#
#
# t-test and r-test for Forest (%) and % of Total Population
# ****************************************
# t-statistic: 7.94
# p-value: 0.00000
# r-value: -0.59
# p-value (r-test): 0.00014
#
#
# t-test and r-test for Forest (%) and Inhabitants per km2
# ****************************************
# t-statistic: -4.81
# p-value: 0.00001
# r-value: -0.63
# p-value (r-test): 0.00004
#
#
# t-test and r-test for Others (%) and Water Bodies (%)
# ****************************************
# t-statistic: 0.47
# p-value: 0.63929
# r-value: 0.24
# p-value (r-test): 0.15672
#
#
# t-test and r-test for Others (%) and Total Population
# ****************************************
# t-statistic: -13.24
# p-value: 0.00000
# r-value: 0.25
# p-value (r-test): 0.14502
#
#
# t-test and r-test for Others (%) and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.25
# p-value (r-test): 0.14382
#
#
# t-test and r-test for Others (%) and Male
# ****************************************
# t-statistic: -13.26
# p-value: 0.00000
# r-value: 0.25
# p-value (r-test): 0.14645
#
#
# t-test and r-test for Others (%) and (Female) % of Population
# ****************************************
# t-statistic: -266.55
# p-value: 0.00000
# r-value: 0.00
# p-value (r-test): 0.98511
#
#
# t-test and r-test for Others (%) and (Male) % of Population
# ****************************************
# t-statistic: -260.03
# p-value: 0.00000
# r-value: -0.00
# p-value (r-test): 0.98511
#
#
# t-test and r-test for Others (%) and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -192.89
# p-value: 0.00000
# r-value: -0.05
# p-value (r-test): 0.78679
#
#
# t-test and r-test for Others (%) and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -218.14
# p-value: 0.00000
# r-value: 0.05
# p-value (r-test): 0.78679
#
#
# t-test and r-test for Others (%) and % of Total Population
# ****************************************
# t-statistic: -12.35
# p-value: 0.00000
# r-value: 0.13
# p-value (r-test): 0.43549
#
#
# t-test and r-test for Others (%) and Inhabitants per km2
# ****************************************
# t-statistic: -5.18
# p-value: 0.00000
# r-value: 0.07
# p-value (r-test): 0.67684
#
#
# t-test and r-test for Water Bodies (%) and Total Population
# ****************************************
# t-statistic: -13.24
# p-value: 0.00000
# r-value: 0.11
# p-value (r-test): 0.53595
#
#
# t-test and r-test for Water Bodies (%) and Female
# ****************************************
# t-statistic: -13.21
# p-value: 0.00000
# r-value: 0.11
# p-value (r-test): 0.52905
#
#
# t-test and r-test for Water Bodies (%) and Male
# ****************************************
# t-statistic: -13.26
# p-value: 0.00000
# r-value: 0.10
# p-value (r-test): 0.54327
#
#
# t-test and r-test for Water Bodies (%) and (Female) % of Population
# ****************************************
# t-statistic: -126.31
# p-value: 0.00000
# r-value: 0.16
# p-value (r-test): 0.36065
#
#
# t-test and r-test for Water Bodies (%) and (Male) % of Population
# ****************************************
# t-statistic: -123.24
# p-value: 0.00000
# r-value: -0.16
# p-value (r-test): 0.36065
#
#
# t-test and r-test for Water Bodies (%) and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: -109.57
# p-value: 0.00000
# r-value: -0.38
# p-value (r-test): 0.02281
#
#
# t-test and r-test for Water Bodies (%) and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -123.86
# p-value: 0.00000
# r-value: 0.38
# p-value (r-test): 0.02281
#
#
# t-test and r-test for Water Bodies (%) and % of Total Population
# ****************************************
# t-statistic: -11.51
# p-value: 0.00000
# r-value: 0.51
# p-value (r-test): 0.00145
#
#
# t-test and r-test for Water Bodies (%) and Inhabitants per km2
# ****************************************
# t-statistic: -5.18
# p-value: 0.00000
# r-value: 0.57
# p-value (r-test): 0.00027
#
#
# t-test and r-test for Total Population and Female
# ****************************************
# t-statistic: 5.84
# p-value: 0.00000
# r-value: 1.00
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Total Population and Male
# ****************************************
# t-statistic: 6.00
# p-value: 0.00000
# r-value: 1.00
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Total Population and (Female) % of Population
# ****************************************
# t-statistic: 13.23
# p-value: 0.00000
# r-value: -0.11
# p-value (r-test): 0.52774
#
#
# t-test and r-test for Total Population and (Male) % of Population
# ****************************************
# t-statistic: 13.23
# p-value: 0.00000
# r-value: 0.11
# p-value (r-test): 0.52774
#
#
# t-test and r-test for Total Population and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 13.23
# p-value: 0.00000
# r-value: 0.15
# p-value (r-test): 0.37493
#
#
# t-test and r-test for Total Population and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: 13.23
# p-value: 0.00000
# r-value: -0.15
# p-value (r-test): 0.37493
#
#
# t-test and r-test for Total Population and % of Total Population
# ****************************************
# t-statistic: 13.24
# p-value: 0.00000
# r-value: 0.07
# p-value (r-test): 0.68174
#
#
# t-test and r-test for Total Population and Inhabitants per km2
# ****************************************
# t-statistic: 13.18
# p-value: 0.00000
# r-value: 0.15
# p-value (r-test): 0.36709
#
#
# t-test and r-test for Female and Male
# ****************************************
# t-statistic: 0.21
# p-value: 0.83357
# r-value: 1.00
# p-value (r-test): 0.00000
#
#
# t-test and r-test for Female and (Female) % of Population
# ****************************************
# t-statistic: 13.20
# p-value: 0.00000
# r-value: -0.09
# p-value (r-test): 0.60135
#
#
# t-test and r-test for Female and (Male) % of Population
# ****************************************
# t-statistic: 13.20
# p-value: 0.00000
# r-value: 0.09
# p-value (r-test): 0.60135
#
#
# t-test and r-test for Female and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 13.20
# p-value: 0.00000
# r-value: 0.16
# p-value (r-test): 0.34940
#
#
# t-test and r-test for Female and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: 13.20
# p-value: 0.00000
# r-value: -0.16
# p-value (r-test): 0.34940
#
#
# t-test and r-test for Female and % of Total Population
# ****************************************
# t-statistic: 13.21
# p-value: 0.00000
# r-value: 0.07
# p-value (r-test): 0.69819
#
#
# t-test and r-test for Female and Inhabitants per km2
# ****************************************
# t-statistic: 13.10
# p-value: 0.00000
# r-value: 0.16
# p-value (r-test): 0.35658
#
#
# t-test and r-test for Male and (Female) % of Population
# ****************************************
# t-statistic: 13.25
# p-value: 0.00000
# r-value: -0.13
# p-value (r-test): 0.45726
#
#
# t-test and r-test for Male and (Male) % of Population
# ****************************************
# t-statistic: 13.25
# p-value: 0.00000
# r-value: 0.13
# p-value (r-test): 0.45726
#
#
# t-test and r-test for Male and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 13.25
# p-value: 0.00000
# r-value: 0.14
# p-value (r-test): 0.40247
#
#
# t-test and r-test for Male and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: 13.25
# p-value: 0.00000
# r-value: -0.14
# p-value (r-test): 0.40247
#
#
# t-test and r-test for Male and % of Total Population
# ****************************************
# t-statistic: 13.26
# p-value: 0.00000
# r-value: 0.07
# p-value (r-test): 0.66514
#
#
# t-test and r-test for Male and Inhabitants per km2
# ****************************************
# t-statistic: 13.15
# p-value: 0.00000
# r-value: 0.15
# p-value (r-test): 0.37829
#
#
# t-test and r-test for (Female) % of Population and (Male) % of Population
# ****************************************
# t-statistic: 8.95
# p-value: 0.00000
# r-value: -1.00
# p-value (r-test): 0.00000
#
#
# t-test and r-test for (Female) % of Population and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 17.96
# p-value: 0.00000
# r-value: 0.33
# p-value (r-test): 0.05306
#
#
# t-test and r-test for (Female) % of Population and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -11.94
# p-value: 0.00000
# r-value: -0.33
# p-value (r-test): 0.05306
#
#
# t-test and r-test for (Female) % of Population and % of Total Population
# ****************************************
# t-statistic: 52.07
# p-value: 0.00000
# r-value: -0.06
# p-value (r-test): 0.74293
#
#
# t-test and r-test for (Female) % of Population and Inhabitants per km2
# ****************************************
# t-statistic: -4.64
# p-value: 0.00002
# r-value: 0.22
# p-value (r-test): 0.20083
#
#
# t-test and r-test for (Male) % of Population and (Female) % of Foreigner_s Population
# ****************************************
# t-statistic: 11.94
# p-value: 0.00000
# r-value: -0.33
# p-value (r-test): 0.05306
#
#
# t-test and r-test for (Male) % of Population and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -17.96
# p-value: 0.00000
# r-value: 0.33
# p-value (r-test): 0.05306
#
#
# t-test and r-test for (Male) % of Population and % of Total Population
# ****************************************
# t-statistic: 50.49
# p-value: 0.00000
# r-value: 0.06
# p-value (r-test): 0.74293
#
#
# t-test and r-test for (Male) % of Population and Inhabitants per km2
# ****************************************
# t-statistic: -4.66
# p-value: 0.00001
# r-value: -0.22
# p-value (r-test): 0.20083
#
#
# t-test and r-test for (Female) % of Foreigner_s Population and (Male) % of Foreigner_s Population
# ****************************************
# t-statistic: -24.03
# p-value: 0.00000
# r-value: -1.00
# p-value (r-test): 0.00000
#
#
# t-test and r-test for (Female) % of Foreigner_s Population and % of Total Population
# ****************************************
# t-statistic: 46.49
# p-value: 0.00000
# r-value: -0.32
# p-value (r-test): 0.05450
#
#
# t-test and r-test for (Female) % of Foreigner_s Population and Inhabitants per km2
# ****************************************
# t-statistic: -4.68
# p-value: 0.00001
# r-value: -0.16
# p-value (r-test): 0.33847
#
#
# t-test and r-test for (Male) % of Foreigner_s Population and % of Total Population
# ****************************************
# t-statistic: 54.19
# p-value: 0.00000
# r-value: 0.32
# p-value (r-test): 0.05450
#
#
# t-test and r-test for (Male) % of Foreigner_s Population and Inhabitants per km2
# ****************************************
# t-statistic: -4.62
# p-value: 0.00002
# r-value: 0.16
# p-value (r-test): 0.33847
#
#
# t-test and r-test for % of Total Population and Inhabitants per km2
# ****************************************
# t-statistic: -5.08
# p-value: 0.00000
# r-value: 0.84
# p-value (r-test): 0.00000
