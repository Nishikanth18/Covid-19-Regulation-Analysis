# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn import set_config
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from pylab import rcParams


set_config(display='diagram')

# %%
df = pd.read_excel("Ludwigshafen_50km.xlsx")


df = df.drop(["Location","State","State (Short)", "Location Type (Larger/Smaller than LHF)"],axis=1)

# %%
pearsoncorr = df.corr(method='pearson')
pearsoncorr

rcParams['figure.figsize'] = 14.7,8.27
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
figure = fig.get_figure()    
figure.savefig('causality_pearson_3g.png', dpi=400)

# %%
kendall = df.corr(method='kendall')

rcParams['figure.figsize'] = 14.7,8.27
sb.heatmap(kendall, 
            xticklabels=kendall.columns,
            yticklabels=kendall.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
kendall = df.corr(method='spearman')

rcParams['figure.figsize'] = 14.7,8.27
fig = sb.heatmap(kendall, 
            xticklabels=kendall.columns,
            yticklabels=kendall.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)

# %%
figure = fig.get_figure()    
figure.savefig('ludwigshafen_spearman.png', dpi=400)
